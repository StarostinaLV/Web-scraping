# %% [markdown]
# **Домашнее задание к лекции "Основы веб-скрапинга"**
#
# **Обязательная часть**
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# <дата> - <заголовок> - <ссылка на материал>
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import pandas as pd
import requests

# %%
# Сформируем поисовый запрос.

habr_res = requests.get('https://habr.com/ru/search/?q=json&target_type=posts&order=relevance')
habr_res
# Out:
# <Response [200]>

# %%
# Импорт библиотеки BeautifulSoup и создание на ее основе объекта soup:
from bs4 import BeautifulSoup
#soup = BeautifulSoup(habr_res.text)
#soup

# %%
# Библиотека time - для создания задержки между запросами.
import time

def habr_search(query):
    habr_df = pd.DataFrame()
    for el in query:
      # Чтобы получать русскоязычные ресурсы, URL заишем в следующем виде (согласно записи Request URL в DevTools):
      URL = 'https://habr.com/ru/search/'
      # Параметр для обозначения строки поискового запроса на сайте habr.com обозначен буквой q, остальные параметры оставим по умолчанию:
      params = {'q': el}
      req = requests.get(URL, params=params)
      time.sleep(0.3)
      soup = BeautifulSoup(req.text)
      articles = soup.find_all('article', class_='tm-articles-list__item')
      for article in articles:
        # Чтобы в датафрейме все даты были в едином формате, обратимся к атрибуту datetime и возьмем его часть [0:10] (не захватывая время):
        date = article.find('time').get('datetime')[0:10]
        title = article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').text
        link_1 = article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').find('a').get('href')
        # Чтобы ссылки в датафрейм добавлялись полноценные:
        link = 'https://habr.com' + link_1
        row = {'Дата': date, 'Заголовок': title, 'Ссылка_на_материал': link}
        habr_df = pd.concat([habr_df, pd.DataFrame([row])])
    # Чтобы материалы в датафрейме не дублировались, удалим дубликаты; а также сбросим индексы (нумерацию строк):
    return habr_df.drop_duplicates().reset_index(drop=True)

query = ['python', 'python для инженеров', 'data science']
habr_search(query)
# Результирующий датафрейм содержит меньше 60строк, значит дубликаты строк удалились.
# Out:
#           Дата                                          Заголовок  \
# 0   2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...
# 1   2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...
# 2   2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 3   2021-07-06  Python Community Meetup 8/07: видео и материал...
# 4   2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...
# 5   2020-12-04  Python как компилируемый статически типизирова...
# 6   2022-03-08  Вышел мартовский релиз расширения Python для V...
# 7   2020-03-03  В начале этого года Python сместил Java и стал...
# 8   2021-11-16  EPAM разработала бесплатный курс по программир...
# 9   2022-08-19  Осталась неделя до старта 4 потока Python для ...
# 10  2020-06-03  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 11  2020-11-13  Создатель Python Гвидо ван Россум выходит на р...
# 12  2019-10-31  Создатель Python Гвидо ван Россум ушел из Drop...
# 13  2021-10-06          Вышел язык программирования Python 3.10.0
# 14  2021-10-11  Python вышел на первое место рейтинга TIOBE, и...
# 15  2022-06-03  «Тестирование веб-приложений на Python» — новы...
# 16  2022-08-24  Python, SQL, С и Java стали самыми популярными...
# 17  2020-09-16  Астрономам порекомендовали меньше использовать...
# 18  2022-01-15  Разработчик предложил устроить коммунистическу...
# 19  2022-05-18  Слёрм запускает 3-дневный интенсив по Python д...
# 20  2022-08-03   Последний поток Python для инженеров в этом году
# 21  2021-09-27  «Разработчикам вход запрещен» или курс «Python...
# 22  2022-05-24  Дайджест Слёрма: тест на уровень кунг-фу по Py...
# 23  2022-07-25  Что не так с курсами по программированию, и за...
# 24  2022-09-07  GOдный контент: 4 поток курса «Golang для инже...
# 25  2021-04-27       Python for Ops, разработчикам вход воспрещён
# 26  2020-09-18  Pysa: как избежать проблем безопасности в коде...
# 27  2017-10-20  “Без data engineer-а ценность модели аналитика...
# 28  2022-08-09  Книга «Python для сетевых инженеров. Автоматиз...
# 29  2021-06-30  Зачем инженеру эксплуатации знать Python: три ...
# 30  2021-12-29  TalkPython: лучшие пакеты Python по итогам 202...
# 31  2017-05-10         Что должен знать сетевой инженер? Чек-лист
# 32  2021-10-22              Зарплаты в Python за последние 10 лет
# 33  2018-02-08  7 бесплатных курсов по Data Science для начина...
# 34  2021-03-11  Как мы сделали первый Data Science Акселератор...
# 35  2019-08-26  Moscow Data Science Major August 2019: програм...
# 36  2021-10-24                           Citymobil Data Meetup №3
# 37  2021-04-27        Соревнования по Data Science от OTUS и КРОК
# 38  2021-12-15  МКБ подвел итоги первого хакатона для специали...
# 39  2020-10-03           Data Fest: трек МегаФона по data science
# 40  2022-07-29  Data Science Meet Up #2: LTV, Uplift, совершен...
# 41  2021-11-18                           Citymobil Data Meetup №4
# 42  2020-05-26                               Квиз, плиз! BIG DATA
# 43  2021-12-20                              Citymobil Data Meetup
# 44  2022-01-20                           Citymobil Data Meetup №6
# 45  2021-09-15                           Citymobil Data Meetup #2
# 46  2020-02-25  29 февраля в ЦДП состоится X5 RetailHero: как ...
# 47  2021-08-10                              Citymobil Data Meetup
# 48  2022-02-18                           Citymobil Data Meetup №7
# 49  2021-11-12  Создаём нейросеть: бесплатный двухнедельный ку...
# 50  2021-08-09          Прямые эфиры со спикерами из Data Science
# 51  2021-08-04   Вебинар «The A-Z of Data: Introduction to MLOps»
# 52  2021-11-12             Онлайн-митап LaTech Data Talks — анонс
#
#                                    Ссылка_на_материал
# 0   https://habr.com/ru/company/southbridge/news/t...
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2                  https://habr.com/ru/news/t/498364/
# 3   https://habr.com/ru/company/raiffeisenbank/new...
# 4   https://habr.com/ru/company/southbridge/news/t...
# 5                  https://habr.com/ru/news/t/531402/
# 6                  https://habr.com/ru/news/t/654707/
# 7   https://habr.com/ru/company/itsumma/news/t/490...
# 8   https://habr.com/ru/company/epam_systems/news/...
# 9   https://habr.com/ru/company/southbridge/news/t...
# 10                 https://habr.com/ru/news/t/505096/
# 11                 https://habr.com/ru/news/t/527858/
# 12                 https://habr.com/ru/news/t/473926/
# 13                 https://habr.com/ru/news/t/581862/
# 14                 https://habr.com/ru/news/t/582682/
# 15  https://habr.com/ru/company/yandex_praktikum/n...
# 16                 https://habr.com/ru/news/t/684376/
# 17                 https://habr.com/ru/news/t/519414/
# 18                 https://habr.com/ru/news/t/645777/
# 19  https://habr.com/ru/company/southbridge/news/t...
# 20  https://habr.com/ru/company/southbridge/news/t...
# 21  https://habr.com/ru/company/southbridge/news/t...
# 22  https://habr.com/ru/company/southbridge/news/t...
# 23  https://habr.com/ru/company/jetinfosystems/blo...
# 24  https://habr.com/ru/company/southbridge/news/t...
# 25  https://habr.com/ru/company/southbridge/blog/5...
# 26  https://habr.com/ru/company/skillfactory/blog/...
# 27  https://habr.com/ru/company/newprolab/blog/340...
# 28     https://habr.com/ru/company/piter/blog/681618/
# 29  https://habr.com/ru/company/southbridge/blog/5...
# 30  https://habr.com/ru/company/skillfactory/blog/...
# 31  https://habr.com/ru/company/tssolution/blog/32...
# 32  https://habr.com/ru/company/skillfactory/blog/...
# 33  https://habr.com/ru/company/icanchoose/blog/34...
# 34  https://habr.com/ru/company/skillfactory/news/...
# 35      https://habr.com/ru/company/vk/news/t/465035/
# 36  https://habr.com/ru/company/citymobil/news/t/5...
# 37    https://habr.com/ru/company/otus/news/t/554690/
# 38     https://habr.com/ru/company/mkb/news/t/595849/
# 39  https://habr.com/ru/company/megafon/news/t/521...
# 40    https://habr.com/ru/company/alfa/news/t/679928/
# 41  https://habr.com/ru/company/citymobil/news/t/5...
# 42  https://habr.com/ru/company/megafon/news/t/503...
# 43  https://habr.com/ru/company/citymobil/news/t/5...
# 44  https://habr.com/ru/company/citymobil/news/t/6...
# 45  https://habr.com/ru/company/citymobil/news/t/5...
# 46                 https://habr.com/ru/news/t/489866/
# 47  https://habr.com/ru/company/citymobil/news/t/5...
# 48  https://habr.com/ru/company/citymobil/news/t/6...
# 49  https://habr.com/ru/company/netologyru/news/t/...
# 50  https://habr.com/ru/company/megafon/news/t/571...
# 51                 https://habr.com/ru/news/t/571236/
# 52  https://habr.com/ru/company/lamoda/news/t/588641/

# %% [markdown]
# **Дополнительная часть (необязательная)**
#
# Функция из обязательной части задания должна быть расширена следующим образом:
#
# кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
# в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
import time
# Функция будет принимать два параметра: список поисковых запросов и количество страниц:
def habr_search_3(query, pages):
    habr_df = pd.DataFrame()
    # Для каждого поискового запроса из списка query будем проходить всё заданное количество страниц pages, формируя строки с заданными столбцами и добавляя их в датафрейм.
    for el in query:

      for page_num in range(1, pages + 1):
        # Т.к. номер страницы имеется в request url (https://habr.com/ru/search/page1...), то задавать номер страницы будем, изменяя число после слова page,
        # оформим это с помощью f-строки:
        URL = f"https://habr.com/ru/search/page{page_num}/"

        params = {'q': el}

        req = requests.get(URL, params=params)
        time.sleep(0.3)
        soup = BeautifulSoup(req.text)
        articles = soup.find_all('article', class_='tm-articles-list__item')
        for article in articles:
          date = article.find('time').get('datetime')[0:10]
          title = article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').text

          link = 'https://habr.com' + article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').find('a').get('href')
          req_text = requests.get(link).text
          soup_text = BeautifulSoup(req_text)
          time.sleep(0.3)
          # Чтобы обойтии проблему, вследствие которой не открываются полные тексты некоторых постов, попавших в результаты поиска, как, например,
          # пост "EPAM разработала бесплатный курс по программированию" (строка №8 в датафрейме), воспользуемся инструкцией 'try-except':
          try: full_text = soup_text.find('div', class_ = 'article-formatted-body').text.strip()
          except: full_text = '-'

          likes = article.find('span', class_ = 'tm-votes-meter__value').text

          row = {'Дата': date, 'Заголовок': title, 'Ссылка_на_материал': link, 'Текст_материала' : full_text, 'Количество_лайков' : likes}
          habr_df = pd.concat([habr_df, pd.DataFrame([row])])

    return habr_df.drop_duplicates().reset_index(drop=True)

# Зададим в качестве параметров функции habr_search_3 список из 2-х поисковых запросов и количество страниц, равное трем:
data_2 = habr_search_3(['python', 'python для инженеров'], 3)
data_2
# Общее количество строк меньше 120 (20 постов х 2 поисковых запроса х 3 страницы), т.к. удалены дубликаты.
# Out:
#            Дата                                          Заголовок  \
# 0    2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...
# 1    2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...
# 2    2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 3    2021-07-06  Python Community Meetup 8/07: видео и материал...
# 4    2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...
# ..          ...                                                ...
# 104  2022-04-05  CLD — Open source проект для ИТ компаний и SRE...
# 105  2015-01-05  SageMathCloud — мечта для любителей Python, ма...
# 106  2018-12-14  Методика оценки знаний инженера. Путь архитект...
# 107  2022-03-14  Рисуем красивые трейсбеки, перехватывая исключ...
# 108  2022-09-12                                  Подтесты в Python
#
#                                     Ссылка_на_материал  \
# 0    https://habr.com/ru/company/southbridge/news/t...
# 1    https://habr.com/ru/company/southbridge/news/t...
# 2                   https://habr.com/ru/news/t/498364/
# 3    https://habr.com/ru/company/raiffeisenbank/new...
# 4    https://habr.com/ru/company/southbridge/news/t...
# ..                                                 ...
# 104                   https://habr.com/ru/post/659023/
# 105                   https://habr.com/ru/post/247277/
# 106                   https://habr.com/ru/post/433226/
# 107  https://habr.com/ru/company/wunderfund/blog/65...
# 108  https://habr.com/ru/company/wunderfund/blog/68...
#
#                                        Текст_материала Количество_лайков
# 0    21 декабря Слёрм проведёт открытый урок «ChatO...                +9
# 1    Курс нацелен дать максимальную пользу, поэтому...               +10
# 2    20 апреля 2020 года, спустя почти десять лет п...               +19
# 3    Первый открытый онлайн-митап сообщества, для к...                +3
# 4    19 января Слёрм проведёт открытый урок «Пишем ...               +10
# ..                                                 ...               ...
# 104  CLD это система для обеспечения комплексной ин...                +5
# 105  SageMathCloud (сокращённо SMC) — это онлайновы...               +49
# 106  Можно ли на одной картинке представить уровень...               +16
# 107  Все мы тратим немало времени на отладку, копая...               +27
# 108  Недавно я сделал опрометчивый твит, в котором ...               +22
#
# [109 rows x 5 columns]
